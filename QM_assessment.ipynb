# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy as sp

import scipy.stats as sps

# %%
#查找outlier
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

csv = pd.read_csv("region1.csv")
sns.set_theme(style="whitegrid")
sns.boxplot(x=csv["rate"],y=csv["region"],order=["North","Midlands","South_exclude_London", "London"])

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
# set a grey background (use sns.set_theme() if seaborn version 0.11.0 or above) 
sns.set(style="darkgrid")
pop = pd.read_csv("pop2.csv")
 
# plotting both distibutions on the same figure
sns.kdeplot(data=pop, x="change_in_rate(10^4)", hue="region")

change_in_rate_densityplot = plt.gcf()
plt.show()
plt.draw()
change_in_rate_densityplot.savefig('Density_change_in_rate(10^4).png', dpi=100)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
# set a grey background (use sns.set_theme() if seaborn version 0.11.0 or above) 
sns.set(style="darkgrid")
pop = pd.read_csv("pop.csv")
 
# plotting both distibutions on the same figure
sns.kdeplot(data=pop, x="change_in_rate(10^4)", hue="region_original")

change_in_rate_densityplot = plt.gcf()
plt.show()
plt.draw()
change_in_rate_densityplot.savefig('Density_change_in_rate(10^4)_3parts.png', dpi=100)

# %%
d1 = pd.read_csv("test.csv")

d1.head()
# Out:
#     local_authority_area  2008_cases_total  2008rate  2013_cases_total  \
# 0        Isles of Scilly                 5  0.002273                 1
# 1  Blackburn with Darwen               831  0.005920               818
# 2                 Newham               568  0.002327               669
# 3                Bromley               611  0.001970               737
# 4          Tower Hamlets               569  0.002492               505
#
#    Unnamed: 4  2018_cases_total  2018rate  2018-2008_rate_of_fatness  \
# 0      0.0004                 4  0.001639                  -0.000633
# 1      0.0061               962  0.006764                   0.000844
# 2      0.0028               710  0.002992                   0.000665
# 3      0.0023               935  0.002776                   0.000806
# 4      0.0026               605  0.003230                   0.000739
#
#    change_in_rate(10^4)  2008_pop_total  ...  school_awareness  \
# ...

# %% [markdown]
# Whole England

# %%
import pandas as pd
df=pd.read_csv("test.csv")

England=df[["change_in_rate(10^4)","clean_air_change","clean_environ_change","health_training_change",
                     "school_awareness_change", "media_awareness_change", "sub_counselling_change"]]
England
# Out:
#      change_in_rate(10^4)  clean_air_change  clean_environ_change  \
# 0                8.438521            0.1648                0.1758
# 1                6.653220            0.1550                0.2250
# 2                8.057698            0.1103                0.2759
# 3                7.388082            0.1714                0.3333
# 4                8.165359            0.2538                0.3231
# ..                    ...               ...                   ...
# 146              0.263667            0.1900                0.2850
# 147             -0.981922            0.0289                0.4158
# 148             -2.916419            0.3333                0.0980
# 149              0.888667            0.2036                0.1900
# 150             -1.374453            0.1381                0.2524
#
#      health_training_change  school_awareness_change  media_awareness_change  \
# 0                    0.1429                   0.2308                0.197802
# ...

# %% [markdown]
# North

# %%
import pandas as pd
df=pd.read_csv("test.csv")
North=df[df['region_divide']=='North']

North=North[["change_in_rate(10^4)","clean_air_change","clean_environ_change","health_training_change",
                     "school_awareness_change", "media_awareness_change", "sub_counselling_change"]]
North
# Out:
#      change_in_rate(10^4)  clean_air_change  clean_environ_change  \
# 0                8.438521            0.1648                0.1758
# 10               5.466886            0.2885                0.2462
# 11               5.640425            0.3488                0.0676
# 12               7.009040            0.2935                0.1419
# 16               6.347799            0.0643                0.2398
# 17               6.609043            0.1278                0.3444
# 21               6.890614            0.2901                0.1298
# 24               4.481439            0.0792                0.4375
# 27               4.874975            0.3301                0.2249
# 29               7.337963            0.2286                0.1429
# 31               5.029868            0.2736                0.3383
# 33               7.052961            0.0357                0.2786
# 38               4.559458            0.2563                0.2813
# ...

# %% [markdown]
# Mid

# %%
import pandas as pd
df=pd.read_csv("test.csv")
Mid=df[df['region_divide']=='Midlands']

Mid=Mid[["change_in_rate(10^4)","clean_air_change","clean_environ_change","health_training_change",
                     "school_awareness_change", "media_awareness_change", "sub_counselling_change"]]
Mid
# Out:
#      change_in_rate(10^4)  clean_air_change  clean_environ_change  \
# 6                0.263667            0.1900                0.2850
# 14               0.888667            0.2036                0.1900
# 16               0.936321            0.2349                0.3893
# 17               0.971355            0.2533                0.2382
# 19               1.028107            0.2383                0.1242
# 22               1.093945            0.1273                0.0364
# 28               1.426316            0.1932                0.3386
# 36               1.772302            0.2707                0.1931
# 42               1.918385            0.0333                0.4250
# 44               1.994405            0.3966                0.1339
# 46               2.176438            0.2816                0.3084
# 49               2.218932            0.2723                0.2383
# 58               2.519610            0.1082                0.3593
# ...

# %% [markdown]
# South except London

# %%
import pandas as pd
df=pd.read_csv("test.csv")
South=df[df['region_divide']=='South']
South_exceptLondon=South[df['region']!='London']

South_exceptLondon=South_exceptLondon[["2018-2008_rate_of_fatness","clean_air_change","clean_environ_change","health_training_change",
                     "school_awareness_change", "media_awareness_change", "sub_counselling_change"]]
South_exceptLondon
# Out:
# /tmp/ipykernel_1806/405935423.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   South_exceptLondon=South[df['region']!='London']
#      2018-2008_rate_of_fatness  clean_air_change  clean_environ_change  \
# 0                    -0.000137            0.1381                0.2524
# 1                    -0.000098            0.0289                0.4158
# 2                    -0.000096            0.2645                0.2645
# 3                     0.000006            0.2704                0.0181
# 4                     0.000014            0.2522                0.2913
# 5                     0.000018            0.2168                0.2515
# 7                     0.000031            0.2385                0.2308
# 8                     0.000032            0.1414                0.1832
# 9                     0.000056            0.2050                0.2609
# 10                    0.000062            0.2987                0.2021
# ...

# %% [markdown]
# London

# %%
import pandas as pd
df=pd.read_csv("test.csv")
London=df[df['region']=='London']


London=London[["2018-2008_rate_of_fatness","clean_air_change","clean_environ_change","health_training_change",
                     "school_awareness_change", "media_awareness_change", "sub_counselling_change"]]
London
# Out:
#     2018-2008_rate_of_fatness  clean_air_change  clean_environ_change  \
# 1                    0.000665            0.1550                0.2250
# 2                    0.000806            0.1103                0.2759
# 3                    0.000739            0.1714                0.3333
# 4                    0.000817            0.2538                0.3231
# 5                    0.001014            0.1598                0.2663
# 6                    0.000752            0.1920                0.3120
# 7                    0.000763            0.1846                0.3000
# 8                    0.000770            0.2302                0.2806
# 13                   0.000608            0.3375                0.0938
# 14                   0.000670            0.2530                0.2731
# 15                   0.000659            0.2044                0.1602
# 18                   0.000735            0.2251                0.1885
# ...

# %% [markdown]
# simple regression in North England

# %%
## simple regression in North England
X = North['school_awareness_change']
Y = North['2018-2008_rate_of_fatness']

plt.xlabel('school_awareness_change')
plt.ylabel('2018-2008_rate_of_fatness')

a = plt.plot(X,Y,'.', label='original data')
#plt.xlim(-1,1)
#plt.ylim(-1,1)

slope, intercept, r_value, p_value, std_err = sps.linregress(X, Y) 

b = plt.plot(X, X*slope + intercept, 'r', label = 'fitted line') # Plot the regression line.

plt.legend()
plt.show()

print("y =", round(slope,3), "x +", round(intercept,3))
print("Rsq = ", r_value**2)
print("p-value = ", p_value)
# Out:
# y = -0.0 x + 0.0
# Rsq =  0.026193599508144195
# p-value =  0.17132155287422196

# %%
London = London.rename(columns = {'2018-2008_rate_of_fatness':'rate',
                                  'clean_air_change':'air',
                                  'clean_environ_change':'environ',
                                  'health_training_change':'training',
                                  'school_awareness_change':'school',
                                  'media_awareness_change':'media',
                                  'sub_counselling_change':'counselling'})

# This performs a multiple regression of wellbeing against greenery and natural light:
multi_London = smf.ols(formula='rate ~ air + environ + training + school + media + counselling',data=London).fit()
#multi_regression_model_London = smf.ols(formula='rate ~ air + environ',data=d1).fit()
# And this gives a big summary of the results:
print(multi_London.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   rate   R-squared:                       0.526
# Model:                            OLS   Adj. R-squared:                  0.416
# Method:                 Least Squares   F-statistic:                     4.806
# Date:                Sat, 13 Nov 2021   Prob (F-statistic):            0.00202
# Time:                        02:53:30   Log-Likelihood:                 250.25
# No. Observations:                  33   AIC:                            -486.5
# Df Residuals:                      26   BIC:                            -476.0
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       0.0634      0.068      0.936      0.358      -0.076       0.202
# ...

# %%
# produce regression plots
fig = plt.figure(figsize=(10,8))
fig = sm.graphics.plot_regress_exog(multi_London, 'air', fig=fig)

# %%
fig = plt.figure(figsize=(10,8))
fig = sm.graphics.plot_regress_exog(multi_London, 'environ', fig=fig)

# %%
fig = plt.figure(figsize=(10,8))
fig = sm.graphics.plot_regress_exog(multi_regression_model_London, 'training', fig=fig)

# %%
fig = plt.figure(figsize=(10,8))
fig = sm.graphics.plot_regress_exog(multi_regression_model_London, 'school', fig=fig)

# %%
fig = plt.figure(figsize=(10,8))
fig = sm.graphics.plot_regress_exog(multi_regression_model_London, 'media', fig=fig)

# %%
fig = plt.figure(figsize=(10,8))
fig = sm.graphics.plot_regress_exog(multi_regression_model_London, 'counselling', fig=fig)

# %% [markdown]
# simple regression in South_exceptLondon

# %%
## simple regression in South_exceptLondon



X = South_exceptLondon['clean_air_change']
Y = South_exceptLondon['change_in_rate(10^4)']

plt.xlabel('clean_air_change')
plt.ylabel('change_in_rate(10^4)')

a = plt.plot(X,Y,'.', label='original data')
#plt.xlim(-1,1)
#plt.ylim(-1,1)

slope, intercept, r_value, p_value, std_err = sps.linregress(X, Y) 

b = plt.plot(X, X*slope + intercept, 'r', label = 'fitted line') # Plot the regression line.

plt.legend()
plt.show()

print("y =", round(slope,3), "x +", round(intercept,3))
print("Rsq = ", r_value**2)
print("p-value = ", p_value)
# Out:
# y = 3.523 x + 0.901
# Rsq =  0.040176612101272303
# p-value =  0.18676612571569384

# %%
## simple regression in South_exceptLondon



X = South_exceptLondon['clean_air_change']
Y = South_exceptLondon['2018-2008_rate_of_fatness']

plt.xlabel('clean_air_change')
plt.ylabel('2018-2008_rate_of_fatness')

a = plt.plot(X,Y,'.', label='original data')
#plt.xlim(-1,1)
#plt.ylim(-1,1)

slope, intercept, r_value, p_value, std_err = sps.linregress(X, Y) 

b = plt.plot(X, X*slope + intercept, 'r', label = 'fitted line') # Plot the regression line.

plt.legend()
plt.show()

print("y =", round(slope,3), "x +", round(intercept,3))
print("Rsq = ", r_value**2)
print("p-value = ", p_value)
# Out:
# y = 0.0 x + 0.0
# Rsq =  0.040176432781350774
# p-value =  0.1867671296030402

# %% [markdown]
# simple regression in whole England

# %%
## simple regression in whole England



X = d1['school_awareness_change']
Y = d1['2018-2008_rate_of_fatness']

plt.xlabel('school_awareness_change')
plt.ylabel('2018-2008_rate_of_fatness')

a = plt.plot(X,Y,'.', label='original data')
#plt.xlim(-1,1)
#plt.ylim(-1,1)

slope, intercept, r_value, p_value, std_err = sps.linregress(X, Y) 

b = plt.plot(X, X*slope + intercept, 'r', label = 'fitted line') # Plot the regression line.

plt.legend()
plt.show()

print("y =", round(slope,3), "x +", round(intercept,3))
print("Rsq = ", r_value**2)
print("p-value = ", p_value)
# Out:
# y = -0.0 x + 0.0
# Rsq =  0.0017386081556271893
# p-value =  0.6100173181089703

# %% [markdown]
# calculating VIF

# %%
# calculating VIF
# This function is partially from: https://stackoverflow.com/a/51329496/4667568
from statsmodels.stats.outliers_influence import variance_inflation_factor 
from statsmodels.tools.tools import add_constant

def drop_column_using_vif_(df, thresh=5):
    '''
    Calculates VIF each feature in a pandas dataframe, and repeatedly drop the columns with the highest VIF
    A constant must be added to variance_inflation_factor or the results will be incorrect

    :param df: the pandas dataframe containing only the predictor features, not the response variable
    :param thresh: the max VIF value before the feature is removed from the dataframe
    :return: dataframe with multicollinear features removed
    '''
    while True:
        # adding a constatnt item to the data
        df_with_const = add_constant(df)

        vif_df = pd.Series([variance_inflation_factor(df_with_const.values, i) 
               for i in range(df_with_const.shape[1])], name= "VIF",
              index=df_with_const.columns).to_frame()

        # drop the const
        vif_df = vif_df.drop('const')
        
        # if the largest VIF is above the thresh, remove a variable with the largest VIF
        if vif_df.VIF.max() > thresh:
            # If there are multiple variables with the maximum VIF, choose the first one
            index_to_drop = vif_df.index[vif_df.VIF == vif_df.VIF.max()].tolist()[0]
            print('Dropping: {}'.format(index_to_drop))
            df = df.drop(columns = index_to_drop)
        else:
            # No VIF is above threshold. Exit the loop
            break

    return df

# %% [markdown]
# multiple regression

# %%
England_new = drop_column_using_vif_(England.drop('change_in_rate(10^4)', axis=1))
# Out:
# Dropping: clean_environ_change
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
England_summary = sm.OLS(endog=England[['change_in_rate(10^4)']], exog=sm.add_constant(England_new)).fit()
England_summary.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ...
# Dep. Variable:     change_in_rate(10^4)   R-squared:                       0.094
# Model:                              OLS   Adj. R-squared:                  0.062
# Method:                   Least Squares   F-statistic:                     2.998
# Date:                  Sat, 13 Nov 2021   Prob (F-statistic):             0.0132
# Time:                          02:22:02   Log-Likelihood:                -338.30
# No. Observations:                   151   AIC:                             688.6
# Df Residuals:                       145   BIC:                             706.7
# Df Model:                             5
# Covariance Type:              nonrobust
# ...
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# ...

# %%
North_new = drop_column_using_vif_(North.drop('change_in_rate(10^4)', axis=1))
# Out:
# Dropping: clean_environ_change
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
North_summary = sm.OLS(endog=North[['change_in_rate(10^4)']], exog=sm.add_constant(North_new)).fit()
North_summary.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ...
# Dep. Variable:     change_in_rate(10^4)   R-squared:                       0.302
# Model:                              OLS   Adj. R-squared:                  0.223
# Method:                   Least Squares   F-statistic:                     3.810
# Date:                  Sat, 13 Nov 2021   Prob (F-statistic):            0.00592
# Time:                          01:16:36   Log-Likelihood:                -86.840
# No. Observations:                    50   AIC:                             185.7
# Df Residuals:                        44   BIC:                             197.2
# Df Model:                             5
# Covariance Type:              nonrobust
# ...
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# ...

# %%
import seaborn as sns
sns.set_theme()

north_mul_plot = pd.read_csv("north_multi_plot.csv")


# Plot sepal width as a function of sepal_length across days
g = sns.lmplot(
    data=north_mul_plot,
    x="rate_in_budget", y="rate_in_fatness", hue="area",
    height=5
)

# Use more informative axis labels than are provided by default
g.set_axis_labels("north_rate_in_budget", "rate_in_childhood_obesity")

#save image
north_multi_plot = plt.gcf()
plt.draw()
north_multi_plot.savefig('north_multi_plot.png', dpi=100)

# %%
Mid_new = drop_column_using_vif_(Mid.drop('change_in_rate(10^4)', axis=1))
# Out:
# Dropping: clean_environ_change
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
Mid_summary = sm.OLS(endog=Mid[['change_in_rate(10^4)']], exog=sm.add_constant(Mid_new)).fit()
Mid_summary.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ...
# Dep. Variable:     change_in_rate(10^4)   R-squared:                       0.615
# Model:                              OLS   Adj. R-squared:                  0.502
# Method:                   Least Squares   F-statistic:                     5.438
# Date:                  Sun, 14 Nov 2021   Prob (F-statistic):            0.00362
# Time:                          22:19:58   Log-Likelihood:                -35.436
# No. Observations:                    23   AIC:                             82.87
# Df Residuals:                        17   BIC:                             89.69
# Df Model:                             5
# Covariance Type:              nonrobust
# ...
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# ...

# %%
Mid_new
# Out:
#      clean_air_change  health_training_change  school_awareness_change  \
# 6              0.1900                  0.0350                   0.3050
# 14             0.2036                  0.1041                   0.3710
# 16             0.2349                  0.0671                   0.2349
# 17             0.2533                  0.1323                   0.3138
# 19             0.2383                  0.0916                   0.3075
# 22             0.1273                  0.0818                   0.4455
# 28             0.1932                  0.1205                   0.1455
# 36             0.2707                  0.0655                   0.2310
# 42             0.0333                  0.1083                   0.3500
# 44             0.3966                  0.1475                   0.0576
# 46             0.2816                  0.0624                   0.1765
# 49             0.2723                  0.1213                   0.1617
# ...

# %%
import seaborn as sns
sns.set_theme()

mid_mul_plot = pd.read_csv("mid_multi_plot.csv")


# Plot sepal width as a function of sepal_length across days
g = sns.lmplot(
    data=mid_mul_plot,
    x="rate_in_budget", y="rate_in_fatness", hue="area",
    height=5
)

# Use more informative axis labels than are provided by default
g.set_axis_labels("midlands_rate_in_budget", "rate_in_childhood_obesity")

#save image
mid_multi_plot = plt.gcf()
plt.draw()
mid_multi_plot.savefig('mid_multi_plot_1.png', dpi=100)

# %%
import seaborn as sns
sns.set_theme()

south_ex_ld = pd.read_csv("south_ex_ld_multi_plot.csv")


# Plot sepal width as a function of sepal_length across days
g = sns.lmplot(
    data=south_ex_ld,
    x="rate_in_budget", y="rate_in_fatness", hue="area",
    height=5
)

# Use more informative axis labels than are provided by default
g.set_axis_labels("south_except_London_rate_in_budget", "rate_in_childhood_obesity")

#save image
south_ex_ld_multi_plot = plt.gcf()
plt.draw()
south_ex_ld_multi_plot.savefig('south_ex_ld_multi_plot_1', dpi=100)

# %%
South_exceptLondon_new = drop_column_using_vif_(South_exceptLondon.drop('2018-2008_rate_of_fatness', axis=1))
# Out:
# Dropping: school_awareness_change
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
South_exceptLondon_summary = sm.OLS(endog=South_exceptLondon[['2018-2008_rate_of_fatness']], exog=sm.add_constant(South_exceptLondon_new)).fit()
South_exceptLondon_summary.summary()
# Out:
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                 OLS Regression Results
# ...
# Dep. Variable:     2018-2008_rate_of_fatness   R-squared:                       0.410
# Model:                                   OLS   Adj. R-squared:                  0.334
# Method:                        Least Squares   F-statistic:                     5.419
# Date:                       Sun, 14 Nov 2021   Prob (F-statistic):           0.000705
# Time:                               23:54:52   Log-Likelihood:                 348.83
# No. Observations:                         45   AIC:                            -685.7
# Df Residuals:                             39   BIC:                            -674.8
# ...

# %%
London_new = drop_column_using_vif_(London.drop('change_in_rate(10^4)', axis=1))
# Out:
# Dropping: clean_environ_change
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
London_summary = sm.OLS(endog=London[['change_in_rate(10^4)']], exog=sm.add_constant(London_new)).fit()
London_summary.summary()
# Out:
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ...
# Dep. Variable:     change_in_rate(10^4)   R-squared:                       0.511
# Model:                              OLS   Adj. R-squared:                  0.420
# Method:                   Least Squares   F-statistic:                     5.633
# Date:                  Sat, 13 Nov 2021   Prob (F-statistic):            0.00111
# Time:                          01:55:34   Log-Likelihood:                -54.220
# No. Observations:                    33   AIC:                             120.4
# Df Residuals:                        27   BIC:                             129.4
# Df Model:                             5
# ...

# %%
import statsmodels.formula.api as smf

# %%
import seaborn as sns
sns.set_theme()

ld = pd.read_csv("London_multi_plot.csv")


# Plot sepal width as a function of sepal_length across days
g = sns.lmplot(
    data=ld,
    x="rate_in_budget", y="rate_in_fatness", hue="area",
    height=5
)

# Use more informative axis labels than are provided by default
g.set_axis_labels("London_rate_in_budget", "rate_in_childhood_obesity")

#save image
London_multi_plot = plt.gcf()
plt.draw()
London_multi_plot.savefig('London_multi_plot', dpi=100)

# %%
import seaborn as sns
sns.set_theme()

north_mul_plot = pd.read_csv("england_multi_plot.csv")


# Plot sepal width as a function of sepal_length across days
g = sns.lmplot(
    data=north_mul_plot,
    x="rate_in_budget", y="rate_in_fatness", hue="area",
    height=5
)

# Use more informative axis labels than are provided by default
g.set_axis_labels("england_rate_in_budget", "rate_in_childhood_obesity")

#save image
north_multi_plot = plt.gcf()
plt.draw()
north_multi_plot.savefig('england_multi_plot.png', dpi=100)
